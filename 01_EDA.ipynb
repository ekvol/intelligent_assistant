# %% [markdown]
# # 01_EDA.ipynb
# Исследовательский анализ данных для интеллектуального помощника абитуриентов.
#
# **Автор**: ФИО студента
#
# **Тема ВКР**: Разработка системы интеллектуального помощника для абитуриентов

# %%
# Импорт необходимых библиотек
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Загрузка данных (пример)
# df = pd.read_csv('https://your-link-to-dataset.csv')
# df.head()
